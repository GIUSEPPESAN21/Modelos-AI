# %% [markdown]
# # Attention LSTM — Maestría

# %% [markdown]
# # Padding Dinámico y Visualización de Atención

# %%
import torch
ckpt = torch.load('../results/trained_models/attention_lstm_best.pt', weights_only=False)
print(ckpt.keys())

# %% [markdown]
# Interpretación de pesos de atención por año.
