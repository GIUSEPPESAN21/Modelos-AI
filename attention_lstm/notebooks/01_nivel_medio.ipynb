# %% [markdown]
# # Attention LSTM — Nivel Medio

# %% [markdown]
# # LSTM con Atención para Series Temporales de Salud

# %%
import sys
sys.path.insert(0, '../..')
from scripts.shared_utils import load_panel_data
df = load_panel_data()
print(df.groupby('country')['life_expectancy'].mean().head())

# %% [markdown]
# ## Entrenar modelo
# ```python
# !python ../src/train.py
# ```
