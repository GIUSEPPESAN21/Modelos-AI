# %% [markdown]
# # Attention LSTM — Doctorado

# %% [markdown]
# # Multi-horizon Forecasting y Transfer Learning

# %% [markdown]
# Extensión a predicción multi-paso y comparación con Transformers.
